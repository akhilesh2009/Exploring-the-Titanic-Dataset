# %% [markdown]
# <a href="https://colab.research.google.com/github/akhilesh2009/Exploring-the-Titanic-Dataset/blob/main/Exploring_the_Titanic_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Study Titanic passengers to find what factors improved survival odds.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("train.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# # **Total Survived**

# %% [markdown]
# Total number of Passengers survived

# %%
total_passengers_survive = train["Survived"].value_counts()[1]
print(total_passengers_survive)
# Out:
# 342

# %% [markdown]
# # **Survival by Gender**

# %%
survival_by_gender = train.groupby("Sex")["Survived"].sum()
survival_by_gender
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %% [markdown]
# Number of Females Survived

# %%
females_survive = survival_by_gender["female"]
print(f"Number of females survived: {females_survive}")
# Out:
# Number of females survived: 233

# %% [markdown]
# Number of males Survived

# %%
males_survives = survival_by_gender["male"]
print(f"Number of males survived: {males_survives}")
# Out:
# Number of males survived: 109

# %% [markdown]
# **Females have higher rate of survival then males**

# %% [markdown]
# Percent of Males Survived

# %%
percent_males_survived = (males_survives / total_passengers_survive) * 100
print(percent_males_survived)
# Out:
# 31.871345029239766

# %% [markdown]
# Percent of Females Survived

# %%
percent_females_survived = (females_survive / total_passengers_survive) * 100
print(percent_females_survived)
# Out:
# 68.12865497076024

# %% [markdown]
# # **Survival rate by Pclass**

# %%
survival_by_class = train.groupby("Pclass")["Survived"].sum()
survival_by_class
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %% [markdown]
# Number of survived passenger from Pclass 1

# %%
survive_class_1 = survival_by_class[1]
survive_class_1
# Out:
# np.int64(136)

# %% [markdown]
# Number of survived passenger from Pclass 2

# %%
survive_class_2 = survival_by_class[2]
survive_class_2
# Out:
# np.int64(87)

# %% [markdown]
# Number of survived passenger from Pclass 3

# %%
survive_class_3 = survival_by_class[3]
survive_class_3
# Out:
# np.int64(119)

# %% [markdown]
# Percent of survived passenger from Pclass 1

# %%
percent_class1_survive = (survive_class_1 / total_passengers_survive) * 100
percent_class1_survive
# Out:
# np.float64(39.76608187134503)

# %% [markdown]
# Percent of survived passenger from Pclass 2

# %%
percent_class2_survive = (survive_class_2 / total_passengers_survive) * 100
percent_class2_survive
# Out:
# np.float64(25.438596491228072)

# %% [markdown]
# Percent of survived passenger from Pclass 3

# %%
percent_class3_survive = (survive_class_3 / total_passengers_survive) * 100
percent_class3_survive
# Out:
# np.float64(34.7953216374269)

# %% [markdown]
# # **Survival rate by Age group**

# %% [markdown]
# Age column

# %%
train["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# People with NaN age

# %%
train[train["Age"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# Total number of people with NaN age survived

# %%
nan_age_survived = len(train[(train["Age"].isna()) & (train["Survived"] == 1)])
nan_age_survived
# Out:
# 52

# %% [markdown]
# minimum age

# %%
train["Age"].min()
# Out:
# 0.42

# %% [markdown]
# maximum age

# %%
train["Age"].max()
# Out:
# 80.0

# %% [markdown]
# Survial rate of Childs

# %%
age_survived = train.groupby("Age")["Survived"].sum()
age_survived
# Out:
# Age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 70.00    0
# 70.50    0
# 71.00    0
# 74.00    0
# 80.00    1
# Name: Survived, Length: 88, dtype: int64

# %% [markdown]
# Survial of people b/w age 0 to 12

# %%
child_survived = age_survived[0:12].sum()
print(child_survived)
# Out:
# 40
# /tmp/ipykernel_1819/367405997.py:1: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   child_survived = age_survived[0:12].sum()

# %% [markdown]
# Survival of people b/w age 13 to 19

# %%
teen_survived = age_survived[13:19].sum()
teen_survived
# Out:
# /tmp/ipykernel_1819/1426549201.py:1: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   teen_survived = age_survived[13:19].sum()
# np.int64(39)

# %% [markdown]
# survival of people b/w age 20 to 39

# %%
adult_survived = age_survived[20:39].sum()
adult_survived
# Out:
# /tmp/ipykernel_1819/4227214267.py:1: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   adult_survived = age_survived[20:39].sum()
# np.int64(150)

# %% [markdown]
# survival of people b/w age 40 to 59

# %%
middle_age_survived = age_survived[50:59].sum()
middle_age_survived
# Out:
# /tmp/ipykernel_1819/1253545223.py:1: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   middle_age_survived = age_survived[50:59].sum()
# np.int64(20)

# %% [markdown]
# survival of people age 60+

# %%
senior_age_survived = age_survived[60:].sum()
senior_age_survived
# Out:
# /tmp/ipykernel_1819/2033758482.py:1: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   senior_age_survived = age_survived[60:].sum()
# np.int64(7)

# %% [markdown]
# percent of child survived

# %%
percent_child_survived = (child_survived / total_passengers_survive) * 100
percent_child_survived
# Out:
# np.float64(11.695906432748536)

# %% [markdown]
# percent teen survived

# %%
percent_teen_survived = (teen_survived / total_passengers_survive) * 100
percent_teen_survived
# Out:
# np.float64(11.403508771929824)

# %% [markdown]
# percent adult survived

# %%
percent_adult_survived = (adult_survived / total_passengers_survive) * 100
percent_adult_survived
# Out:
# np.float64(43.859649122807014)

# %% [markdown]
# percent middled age survived

# %%
percent_middle_age_survived = (middle_age_survived / total_passengers_survive) * 100
percent_middle_age_survived
# Out:
# np.float64(5.847953216374268)

# %% [markdown]
# percent senior age survived

# %%
percent_senior_survived = (senior_age_survived / total_passengers_survive) * 100
percent_senior_survived
# Out:
# np.float64(2.046783625730994)
